# %%
# Necessário para rodar a partir do google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
my_sheet = 'mega_sena_www.asloterias.com.br'
xlsx_file = '/content/drive/My Drive/mega_sena/mega_sena_crescente.xlsx'

df = pd.read_excel(xlsx_file, sheet_name = my_sheet)

# %%
df
# Out:
#       Concurso        Data  bola 1  bola 2  bola 3  bola 4  bola 5  bola 6
# 0         2330  31/12/2020      17      20      22      35      41      42
# 1         2329  19/12/2020      12      14      28      42      45      55
# 2         2328  16/12/2020       8      11      14      39      48      53
# 3         2327  12/12/2020      30      37      45      54      57      58
# 4         2326  10/12/2020      10      16      27      34      36      57
# ...        ...         ...     ...     ...     ...     ...     ...     ...
# 2325         5  08/04/1996       1       2       6      16      19      46
# 2326         4  01/04/1996       1       5       6      27      42      59
# 2327         3  25/03/1996      10      11      29      30      36      47
# 2328         2  18/03/1996       9      37      39      41      43      49
# 2329         1  11/03/1996       4       5      30      33      41      52
#
# [2330 rows x 8 columns]

# %%
col_list= list(df)
col_list.remove('Concurso')
col_list.remove('Data')
col_list
# Out:
# ['bola 1', 'bola 2', 'bola 3', 'bola 4', 'bola 5', 'bola 6']

# %%
df['soma_das_colunas'] = df[col_list].sum(axis=1)

# %%
df
# Out:
#       Concurso        Data  bola 1  ...  bola 5  bola 6  soma_das_colunas
# 0         2330  31/12/2020      17  ...      41      42               177
# 1         2329  19/12/2020      12  ...      45      55               196
# 2         2328  16/12/2020       8  ...      48      53               173
# 3         2327  12/12/2020      30  ...      57      58               281
# 4         2326  10/12/2020      10  ...      36      57               180
# ...        ...         ...     ...  ...     ...     ...               ...
# 2325         5  08/04/1996       1  ...      19      46                90
# 2326         4  01/04/1996       1  ...      42      59               140
# 2327         3  25/03/1996      10  ...      36      47               163
# 2328         2  18/03/1996       9  ...      43      49               218
# 2329         1  11/03/1996       4  ...      41      52               165
#
# [2330 rows x 9 columns]

# %%
import plotly.express as px

# %%
fig = px.line(df, x="Data", y="soma_das_colunas", title='Média da distrubição da soma das dezenas de todos os sorteios')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4dad469c-38b6-4cc0-86d9-349a787c4019" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4dad469c-38b6-4cc0-86d9-349a787c4019")) {
#                     Plotly.newPlot(
#                         '4dad469c-38b6-4cc0-86d9-349a787c4019',
# ...

# %%
fig = px.scatter(df, x="Data", y="soma_das_colunas", title='Média da distrubição da soma das dezenas de todos os sorteios')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9154d6ae-4f33-48f3-959f-27a7be857211" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9154d6ae-4f33-48f3-959f-27a7be857211")) {
#                     Plotly.newPlot(
#                         '9154d6ae-4f33-48f3-959f-27a7be857211',
# ...
